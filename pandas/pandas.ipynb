# %% [markdown]
# <a href="https://colab.research.google.com/github/aiswaryajoseph2004-bot/python/blob/main/pandas/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### **dataframe using python dictionary**

# %%
import pandas as pd
emp={'id':[101,102,103,104,105],
     'name':["deepak","arun","manu","shyam","jeenu"],
     'age':[12,13,16,17,18],
     'salary':[15000,20000,25000,24000,30000]}
df=pd.DataFrame(emp)
df
# Out:
#     id    name  age  salary
# 0  101  deepak   12   15000
# 1  102    arun   13   20000
# 2  103    manu   16   25000
# 3  104   shyam   17   24000
# 4  105   jeenu   18   30000

# %% [markdown]
# ### **dataframe using python tuple list**

# %%
emp_data=[(101,'deepak',12,15000),
          (102,'shyam',13,20000),
          (103,'arun',15,25000),
          (104,'manu',16,26000),
          (105,'jeenu',17,30000)]
df=pd.DataFrame(emp_data,columns=['id','name','age','salary'])
df
# Out:
#     id    name  age  salary
# 0  101  deepak   12   15000
# 1  102   shyam   13   20000
# 2  103    arun   15   25000
# 3  104    manu   16   26000
# 4  105   jeenu   17   30000

# %% [markdown]
# ### **dataframe using python list of dictionary**

# %%
emp_data_list=[{'id':102,'name':"deepak",'age':12,'salary':15000},
          {'id':103,'name':"shyam",'age':14,'salary':20000},
          {'id':104,'name':"arun",'age':17,'salary':25000},
          {'id':105,'name':"jeenu",'age':10,'salary':20000}]
df=pd.DataFrame(emp_data_list)
df
# Out:
#     id    name  age  salary
# 0  102  deepak   12   15000
# 1  103   shyam   14   20000
# 2  104    arun   17   25000
# 3  105   jeenu   10   20000

# %% [markdown]
# ### dataframe using CSV

# %%
df=pd.read_csv("/content/attendance_data.csv")
df
# Out:
#        ID         Name     Role        Date   Time In  Time Out Subject/Class  \
# 0       1  Student_001  Student  2025-01-01  08:58:00  16:00:00       English
# 1       2  Student_002  Student  2025-01-01       NaN       NaN       English
# 2       3  Student_003  Student  2025-01-01  09:03:00  15:56:00       Physics
# 3       4  Student_004  Student  2025-01-01  09:10:00  16:12:00       Physics
# 4       5  Student_005  Student  2025-01-01  09:10:00  15:22:00       Biology
# ...   ...          ...      ...         ...       ...       ...           ...
# 9455  106     Staff_06    Staff  2025-04-30  08:59:00  15:03:00           NaN
# 9456  107     Staff_07    Staff  2025-04-30  08:59:00  16:03:00           NaN
# 9457  108     Staff_08    Staff  2025-04-30  09:22:00  16:26:00           NaN
# 9458  109     Staff_09    Staff  2025-04-30  09:09:00  15:43:00           NaN
# 9459  110     Staff_10    Staff  2025-04-30  08:55:00  16:53:00           NaN
#
# ...

# %%
df.head(1)
# Out:
#    ID         Name     Role        Date   Time In  Time Out Subject/Class  \
# 0   1  Student_001  Student  2025-01-01  08:58:00  16:00:00       English
#
#          Day Attendance Status
# 0  Wednesday           Present

# %%
df.tail()
# Out:
#        ID      Name   Role        Date   Time In  Time Out Subject/Class  \
# 9455  106  Staff_06  Staff  2025-04-30  08:59:00  15:03:00           NaN
# 9456  107  Staff_07  Staff  2025-04-30  08:59:00  16:03:00           NaN
# 9457  108  Staff_08  Staff  2025-04-30  09:22:00  16:26:00           NaN
# 9458  109  Staff_09  Staff  2025-04-30  09:09:00  15:43:00           NaN
# 9459  110  Staff_10  Staff  2025-04-30  08:55:00  16:53:00           NaN
#
#             Day Attendance Status
# 9455  Wednesday           Present
# 9456  Wednesday           Present
# 9457  Wednesday              Late
# 9458  Wednesday           Present
# 9459  Wednesday           Present

# %% [markdown]
# ## **pandas series**

# %%
a=[1,2,3,4]
myvar=pd.Series(a)
myvar
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# ### **labels**

# %%
a=[1,2,3,4]
myvar=pd.Series(a)
print(myvar[0])
# Out:
# 1

# %% [markdown]
# ### **create labels**

# %%
a=[1,2,3]
myvar=pd.Series(a,index=["x","y","z"])
myvar
# Out:
# x    1
# y    2
# z    3
# dtype: int64

# %%
a=[1,2,3]
myvar=pd.Series(a,index=["x","y","z"])
print(myvar["z"])
# Out:
# 3

# %% [markdown]
# ### **key/value objects as series**

# %%
calories={"day1":250,"day2":350,"day3":300}
myvar=pd.Series(calories)
myvar
# Out:
# day1    250
# day2    350
# day3    300
# dtype: int64

# %%
calories={"day1":250,"day2":350,"day3":300}
myvar=pd.Series(calories,index=["day1","day2"])
myvar
# Out:
# day1    250
# day2    350
# dtype: int64

# %%
data=pd.read_csv('/content/sdhfdf.txt',delimiter='/t')
data
# Out:
# /tmp/ipython-input-3322452626.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data=pd.read_csv('/content/sdhfdf.txt',delimiter='/t')
# Empty DataFrame
# Columns: [hello python]
# Index: []

# %%
df=pd.read_excel("/content/weather_data 2.xlsx")
df
# Out:
#    Temperature  Windspeed  Event
# 0         30.0        5.0  Sunny
# 1          NaN        NaN    NaN
# 2         28.0        2.0   Rain
# 3         35.0        8.0  Sunny
# 4         33.0        6.0  Storm

# %%
data=pd.read_csv("/content/attendance_data.csv")
data
# Out:
#        ID         Name     Role        Date   Time In  Time Out Subject/Class  \
# 0       1  Student_001  Student  2025-01-01  08:58:00  16:00:00       English
# 1       2  Student_002  Student  2025-01-01       NaN       NaN       English
# 2       3  Student_003  Student  2025-01-01  09:03:00  15:56:00       Physics
# 3       4  Student_004  Student  2025-01-01  09:10:00  16:12:00       Physics
# 4       5  Student_005  Student  2025-01-01  09:10:00  15:22:00       Biology
# ...   ...          ...      ...         ...       ...       ...           ...
# 9455  106     Staff_06    Staff  2025-04-30  08:59:00  15:03:00           NaN
# 9456  107     Staff_07    Staff  2025-04-30  08:59:00  16:03:00           NaN
# 9457  108     Staff_08    Staff  2025-04-30  09:22:00  16:26:00           NaN
# 9458  109     Staff_09    Staff  2025-04-30  09:09:00  15:43:00           NaN
# 9459  110     Staff_10    Staff  2025-04-30  08:55:00  16:53:00           NaN
#
# ...

# %%
data=pd.read_csv("/content/attendance_data.csv",header=1)
data
# Out:
#        ID         Name     Role        Date   Time In  Time Out Subject/Class  \
# 0       1  Student_001  Student  2025-01-01  08:58:00  16:00:00       English
# 1       2  Student_002  Student  2025-01-01       NaN       NaN       English
# 2       3  Student_003  Student  2025-01-01  09:03:00  15:56:00       Physics
# 3       4  Student_004  Student  2025-01-01  09:10:00  16:12:00       Physics
# 4       5  Student_005  Student  2025-01-01  09:10:00  15:22:00       Biology
# ...   ...          ...      ...         ...       ...       ...           ...
# 9455  106     Staff_06    Staff  2025-04-30  08:59:00  15:03:00           NaN
# 9456  107     Staff_07    Staff  2025-04-30  08:59:00  16:03:00           NaN
# 9457  108     Staff_08    Staff  2025-04-30  09:22:00  16:26:00           NaN
# 9458  109     Staff_09    Staff  2025-04-30  09:09:00  15:43:00           NaN
# 9459  110     Staff_10    Staff  2025-04-30  08:55:00  16:53:00           NaN
#
# ...

# %%
data=pd.read_csv("/content/attendance_data.csv",header=None,
                 names=["Number","Name","role","date","time in","time out","cls","day","status"])
data
# Out:
#      Number         Name     role        date   time in  time out  \
# 0        ID         Name     Role        Date   Time In  Time Out
# 1         1  Student_001  Student  2025-01-01  08:58:00  16:00:00
# 2         2  Student_002  Student  2025-01-01       NaN       NaN
# 3         3  Student_003  Student  2025-01-01  09:03:00  15:56:00
# 4         4  Student_004  Student  2025-01-01  09:10:00  16:12:00
# ...     ...          ...      ...         ...       ...       ...
# 9456    106     Staff_06    Staff  2025-04-30  08:59:00  15:03:00
# 9457    107     Staff_07    Staff  2025-04-30  08:59:00  16:03:00
# 9458    108     Staff_08    Staff  2025-04-30  09:22:00  16:26:00
# 9459    109     Staff_09    Staff  2025-04-30  09:09:00  15:43:00
# 9460    110     Staff_10    Staff  2025-04-30  08:55:00  16:53:00
#
#                 cls        day             status
# 0     Subject/Class        Day  Attendance Status
# 1           English  Wednesday            Present
# ...

# %%
data=pd.read_csv("/content/attendance_data.csv",nrows=3)
data
# Out:
#    ID         Name     Role        Date   Time In  Time Out Subject/Class  \
# 0   1  Student_001  Student  2025-01-01  08:58:00  16:00:00       English
# 1   2  Student_002  Student  2025-01-01       NaN       NaN       English
# 2   3  Student_003  Student  2025-01-01  09:03:00  15:56:00       Physics
#
#          Day Attendance Status
# 0  Wednesday           Present
# 1  Wednesday            Absent
# 2  Wednesday           Present

# %%
data=pd.read_csv("/content/attendance_data.csv")
data
# Out:
#    Unnamed: 0  ID         Name     Role        Date   Time In  Time Out  \
# 0           0   1  Student_001  Student  2025-01-01  08:58:00  16:00:00
# 1           1   2  Student_002  Student  2025-01-01       NaN       NaN
# 2           2   3  Student_003  Student  2025-01-01  09:03:00  15:56:00
#
#   Subject/Class        Day Attendance Status
# 0       English  Wednesday           Present
# 1       English  Wednesday            Absent
# 2       Physics  Wednesday           Present

# %%
data=pd.read_csv("/content/attendance_data.csv")
print(data)
# Out:
#    Unnamed: 0         Name     Role
# 0           0  Student_001  Student
# 1           1  Student_002  Student
# 2           2  Student_003  Student
#    Unnamed: 0         Name     Role
# 0           0  Student_001  Student
# 1           1  Student_002  Student
# 2           2  Student_003  Student

# %%
data.to_csv("aiswarya.csv",columns=["Name","Role"])
# Out:
#        ID         Name     Role        Date   Time In  Time Out Subject/Class  \
# 0       1  Student_001  Student  2025-01-01  08:58:00  16:00:00       English
# 1       2  Student_002  Student  2025-01-01       NaN       NaN       English
# 2       3  Student_003  Student  2025-01-01  09:03:00  15:56:00       Physics
# 3       4  Student_004  Student  2025-01-01  09:10:00  16:12:00       Physics
# 4       5  Student_005  Student  2025-01-01  09:10:00  15:22:00       Biology
# ...   ...          ...      ...         ...       ...       ...           ...
# 9455  106     Staff_06    Staff  2025-04-30  08:59:00  15:03:00           NaN
# 9456  107     Staff_07    Staff  2025-04-30  08:59:00  16:03:00           NaN
# 9457  108     Staff_08    Staff  2025-04-30  09:22:00  16:26:00           NaN
# 9458  109     Staff_09    Staff  2025-04-30  09:09:00  15:43:00           NaN
# 9459  110     Staff_10    Staff  2025-04-30  08:55:00  16:53:00           NaN
#
# ...

# %%
data=pd.read_csv("/content/aiswarya.csv")
data
# Out:
#       Unnamed: 0         Name     Role
# 0              0  Student_001  Student
# 1              1  Student_002  Student
# 2              2  Student_003  Student
# 3              3  Student_004  Student
# 4              4  Student_005  Student
# ...          ...          ...      ...
# 9455        9455     Staff_06    Staff
# 9456        9456     Staff_07    Staff
# 9457        9457     Staff_08    Staff
# 9458        9458     Staff_09    Staff
# 9459        9459     Staff_10    Staff
#
# [9460 rows x 3 columns]

# %%
data=pd.read_excel("/content/Online Retail.xlsx - Online Retail.xlsx")
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
data=pd.read_excel("/content/Online Retail.xlsx - Online Retail.xlsx",na_values=['n.a.','not available'])
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data=pd.read_excel("/content/weather_data 2.xlsx",na_values=['n.a.','not available'])
data
# Out:
#    Temperature  Windspeed  Event
# 0         30.0        5.0  Sunny
# 1          NaN        NaN    NaN
# 2         28.0        2.0   Rain
# 3         35.0        8.0  Sunny
# 4         33.0        6.0  Storm

# %%
data=pd.read_excel("/content/sample_weather_ data.xlsx",na_values=['n.a','not available'])
data
# Out:
#          day temperature  windspeed  event
# 0 2020-01-01          32        6.0   Rain
# 1 2020-01-02          35        7.0  Sunny
# 2 2020-01-03        n.a.        2.0   Snow
# 3 2020-01-04          28        NaN  Sunny
# 4 2020-01-05          30        4.0   Rain
# 5 2020-01-06          32        5.0   n.a.

# %%
data=pd.read_excel("/content/sample_weather_ data.xlsx")
data
# Out:
#          day temperature      windspeed  event
# 0 2020-01-01          32              6   Rain
# 1 2020-01-02          35              7  Sunny
# 2 2020-01-03        n.a.              2   Snow
# 3 2020-01-04          28  not available  Sunny
# 4 2020-01-05          30              4   Rain
# 5 2020-01-06          32              5   n.a.

# %%
data=pd.read_excel("/content/sample_weather_ data.xlsx")
data
# Out:
#          day    temperature      windspeed          event
# 0 2020-01-01             32              6           Rain
# 1 2020-01-02             35              7          Sunny
# 2 2020-01-03  not available              2           Snow
# 3 2020-01-04             28  not available          Sunny
# 4 2020-01-05             30              4           Rain
# 5 2020-01-06             32              5  not available

# %%
data=pd.read_excel("/content/sample_weather_ data.xlsx",na_values=['n.a','not available'])
data
# Out:
#          day  temperature  windspeed  event
# 0 2020-01-01         32.0        6.0   Rain
# 1 2020-01-02         35.0        7.0  Sunny
# 2 2020-01-03          NaN        2.0   Snow
# 3 2020-01-04         28.0        NaN  Sunny
# 4 2020-01-05         30.0        4.0   Rain
# 5 2020-01-06         32.0        5.0    NaN

# %%
data=pd.read_excel("/content/sample_weather_ data.xlsx",header=None,names=['a','b','c','d'])
data
# Out:
#                      a              b              c              d
# 0                  day    temperature      windspeed          event
# 1  2020-01-01 00:00:00             32              6           Rain
# 2  2020-01-02 00:00:00             35              7          Sunny
# 3  2020-01-03 00:00:00  not available              2           Snow
# 4  2020-01-04 00:00:00             28  not available          Sunny
# 5  2020-01-05 00:00:00             30              4           Rain
# 6  2020-01-06 00:00:00             32              5  not available

# %%
def convert_people(co):
  if co=='Tina,Harry':
    return 'Mithun'
  else:
    return co

# %%
data=pd.read_excel("/content/Aiswarya_dataset.xlsx",converters={'people':convert_people})
data
# Out:
#          day  stock_price         people
# 0 2020-01-01          100  Sam,John,Emma
# 1 2020-01-02          102         Mithun
# 2 2020-01-03           98           n.a.
# 3 2020-01-04          105      John,Emma
# 4 2020-01-05          110  not available

# %%
data=pd.read_excel("/content/Aiswarya_dataset.xlsx")
data
# Out:
#          day  stock_price         people
# 0 2020-01-01          100  Sam,John,Emma
# 1 2020-01-02          102     Tina,Harry
# 2 2020-01-03           98           n.a.
# 3 2020-01-04          105      John,Emma
# 4 2020-01-05          110  not available

# %%
import pandas as pd
data=pd.read_excel("/content/Sample - Superstore.xls")
data
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2021-103800 2021-01-03 2021-01-07  Standard Class
# 1           2  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 2           3  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 3           4  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 4           5  US-2021-141817 2021-01-05 2021-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10190   10191  US-2024-115427 2024-12-30 2025-01-03  Standard Class
# 10191   10192  US-2024-156720 2024-12-30 2025-01-03  Standard Class
# 10192   10193  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10193   10194  CA-2024-143500 2024-12-30 2025-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
data.to_excel("datas_edited.xlsx",columns=["Order ID","Order Date"])
df = pd.read_excel("/content/datas_edited.xlsx")
df
# Out:
#        Unnamed: 0        Order ID Order Date
# 0               0  US-2021-103800 2021-01-03
# 1               1  US-2021-112326 2021-01-04
# 2               2  US-2021-112326 2021-01-04
# 3               3  US-2021-112326 2021-01-04
# 4               4  US-2021-141817 2021-01-05
# ...           ...             ...        ...
# 10189       10189  US-2024-143259 2024-12-30
# 10190       10190  US-2024-115427 2024-12-30
# 10191       10191  US-2024-156720 2024-12-30
# 10192       10192  US-2024-143259 2024-12-30
# 10193       10193  CA-2024-143500 2024-12-30
#
# [10194 rows x 3 columns]

# %%
data.to_excel("new_data.xlsx",header=False)
data
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2021-103800 2021-01-03 2021-01-07  Standard Class
# 1           2  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 2           3  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 3           4  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 4           5  US-2021-141817 2021-01-05 2021-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10190   10191  US-2024-115427 2024-12-30 2025-01-03  Standard Class
# 10191   10192  US-2024-156720 2024-12-30 2025-01-03  Standard Class
# 10192   10193  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10193   10194  CA-2024-143500 2024-12-30 2025-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df = pd.read_excel("/content/new_data.xlsx")
df
# Out:
#            0      1  US-2021-103800 2021-01-03 00:00:00 2021-01-07 00:00:00  \
# 0          1      2  US-2021-112326          2021-01-04          2021-01-08
# 1          2      3  US-2021-112326          2021-01-04          2021-01-08
# 2          3      4  US-2021-112326          2021-01-04          2021-01-08
# 3          4      5  US-2021-141817          2021-01-05          2021-01-12
# 4          5      6  US-2021-167199          2021-01-06          2021-01-10
# ...      ...    ...             ...                 ...                 ...
# 10188  10189  10190  US-2024-143259          2024-12-30          2025-01-03
# 10189  10190  10191  US-2024-115427          2024-12-30          2025-01-03
# 10190  10191  10192  US-2024-156720          2024-12-30          2025-01-03
# 10191  10192  10193  US-2024-143259          2024-12-30          2025-01-03
# 10192  10193  10194  CA-2024-143500          2024-12-30          2025-01-03
#
# ...

# %%
df.shape
# Out:
# (10193, 22)

# %%
df.columns
# Out:
# Index([                                                                         0,
#                                                                                 1,
#                                                                  'US-2021-103800',
#                                                               2021-01-03 00:00:00,
#                                                               2021-01-07 00:00:00,
#                                                                  'Standard Class',
#                                                                        'DP-13000',
#                                                                   'Darren Powers',
#                                                                        'Consumer',
#                                                                   'United States',
#                                                                         'Houston',
# ...

# %%
df.head(1)
# Out:
#    0  1  US-2021-103800 2021-01-03 00:00:00 2021-01-07 00:00:00  \
# 0  1  2  US-2021-112326          2021-01-04          2021-01-08
#
#    Standard Class  DP-13000  Darren Powers     Consumer  United States  ...  \
# 0  Standard Class  PO-19195  Phillina Ober  Home Office  United States  ...
#
#    77095  Central  OFF-PA-10000174  Office Supplies    Paper  \
# 0  60540  Central  OFF-BI-10004094  Office Supplies  Binders
#
#   Message Book, Wirebound, Four 5 1/2" X 4" Forms/Pg., 200 Dupl. Sets/Book  \
# 0         GBC Standard Plastic Binding Systems Combs
#
#   16.448  2  0.2  5.5512
# 0   3.54  2  0.8  -5.487
#
# [1 rows x 22 columns]

# %%
data['Order ID']
# Out:
# 0        US-2021-103800
# 1        US-2021-112326
# 2        US-2021-112326
# 3        US-2021-112326
# 4        US-2021-141817
#               ...
# 10189    US-2024-143259
# 10190    US-2024-115427
# 10191    US-2024-156720
# 10192    US-2024-143259
# 10193    CA-2024-143500
# Name: Order ID, Length: 10194, dtype: object

# %%
data[['Order ID','Order Date']]
# Out:
#              Order ID Order Date
# 0      US-2021-103800 2021-01-03
# 1      US-2021-112326 2021-01-04
# 2      US-2021-112326 2021-01-04
# 3      US-2021-112326 2021-01-04
# 4      US-2021-141817 2021-01-05
# ...               ...        ...
# 10189  US-2024-143259 2024-12-30
# 10190  US-2024-115427 2024-12-30
# 10191  US-2024-156720 2024-12-30
# 10192  US-2024-143259 2024-12-30
# 10193  CA-2024-143500 2024-12-30
#
# [10194 rows x 2 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10194, step=1)

# %%
data.set_index('Order Date')
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2021-01-03       1  US-2021-103800 2021-01-07  Standard Class    DP-13000
# 2021-01-04       2  US-2021-112326 2021-01-08  Standard Class    PO-19195
# 2021-01-04       3  US-2021-112326 2021-01-08  Standard Class    PO-19195
# 2021-01-04       4  US-2021-112326 2021-01-08  Standard Class    PO-19195
# 2021-01-05       5  US-2021-141817 2021-01-12  Standard Class    MB-18085
# ...            ...             ...        ...             ...         ...
# 2024-12-30   10190  US-2024-143259 2025-01-03  Standard Class    PO-18865
# 2024-12-30   10191  US-2024-115427 2025-01-03  Standard Class    EB-13975
# 2024-12-30   10192  US-2024-156720 2025-01-03  Standard Class    JM-15580
# 2024-12-30   10193  US-2024-143259 2025-01-03  Standard Class    PO-18865
# 2024-12-30   10194  CA-2024-143500 2025-01-03  Standard Class    HO-15230
#
# ...

# %%
data.reset_index()
# Out:
#        index  Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          0       1  US-2021-103800 2021-01-03 2021-01-07  Standard Class
# 1          1       2  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 2          2       3  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 3          3       4  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 4          4       5  US-2021-141817 2021-01-05 2021-01-12  Standard Class
# ...      ...     ...             ...        ...        ...             ...
# 10189  10189   10190  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10190  10190   10191  US-2024-115427 2024-12-30 2025-01-03  Standard Class
# 10191  10191   10192  US-2024-156720 2024-12-30 2025-01-03  Standard Class
# 10192  10192   10193  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10193  10193   10194  CA-2024-143500 2024-12-30 2025-01-03  Standard Class
#
# ...

# %%
data[2:5]
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2       3  US-2021-112326 2021-01-04 2021-01-08  Standard Class    PO-19195
# 3       4  US-2021-112326 2021-01-04 2021-01-08  Standard Class    PO-19195
# 4       5  US-2021-141817 2021-01-05 2021-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
#     Region       Product ID         Category Sub-Category  \
# 2  Central  OFF-LA-10003223  Office Supplies       Labels
# 3  Central  OFF-ST-10002743  Office Supplies      Storage
# 4     East  OFF-AR-10003478  Office Supplies          Art
#
#                                         Product Name    Sales  Quantity  \
# ...

# %%
data[:]
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2021-103800 2021-01-03 2021-01-07  Standard Class
# 1           2  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 2           3  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 3           4  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 4           5  US-2021-141817 2021-01-05 2021-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10190   10191  US-2024-115427 2024-12-30 2025-01-03  Standard Class
# 10191   10192  US-2024-156720 2024-12-30 2025-01-03  Standard Class
# 10192   10193  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10193   10194  CA-2024-143500 2024-12-30 2025-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
data[['Order Date','Order ID']][2:5]
# Out:
#   Order Date        Order ID
# 2 2021-01-04  US-2021-112326
# 3 2021-01-04  US-2021-112326
# 4 2021-01-05  US-2021-141817

# %%
data.sort_values('Order Date',ascending=True)
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2021-103800 2021-01-03 2021-01-07  Standard Class
# 1           2  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 2           3  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 3           4  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 4           5  US-2021-141817 2021-01-05 2021-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10188   10189  US-2024-115427 2024-12-30 2025-01-03  Standard Class
# 10189   10190  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10190   10191  US-2024-115427 2024-12-30 2025-01-03  Standard Class
# 10191   10192  US-2024-156720 2024-12-30 2025-01-03  Standard Class
# 10193   10194  CA-2024-143500 2024-12-30 2025-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
data["Order ID"].max()
# Out:
# 'US-2024-169999'

# %%
data["Order ID"].min()
# Out:
# 'CA-2021-100867'

# %%
data.describe()
# Out:
#              Row ID                     Order Date  \
# count  10194.000000                          10194
# mean    5097.500000  2023-04-30 00:15:40.788699136
# min        1.000000            2021-01-03 00:00:00
# 25%     2549.250000            2022-05-14 00:00:00
# 50%     5097.500000            2023-06-25 00:00:00
# 75%     7645.750000            2024-05-14 00:00:00
# max    10194.000000            2024-12-30 00:00:00
# std     2942.898656                            NaN
#
#                            Ship Date         Sales      Quantity  \
# count                          10194  10194.000000  10194.000000
# mean   2023-05-03 23:20:43.790465024    228.225854      3.791838
# min              2021-01-07 00:00:00      0.444000      1.000000
# 25%              2022-05-19 00:00:00     17.220000      2.000000
# 50%              2023-06-28 00:00:00     53.910000      3.000000
# 75%              2024-05-18 00:00:00    209.500000      5.000000
# ...

# %%
data.Profit.mean()
# Out:
# np.float64(28.67341716696095)

# %%
data[data.Profit>20]
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 5           6  US-2021-167199 2021-01-06 2021-01-10  Standard Class
# 8           9  US-2021-167199 2021-01-06 2021-01-10  Standard Class
# 12         13  US-2021-167199 2021-01-06 2021-01-10  Standard Class
# 13         14  US-2021-167199 2021-01-06 2021-01-10  Standard Class
# 18         19  US-2021-149020 2021-01-10 2021-01-15  Standard Class
# ...       ...             ...        ...        ...             ...
# 10181   10182  US-2024-158673 2024-12-29 2025-01-04  Standard Class
# 10182   10183  US-2024-118885 2024-12-29 2025-01-02  Standard Class
# 10183   10184  CA-2024-146626 2024-12-29 2025-01-05  Standard Class
# 10184   10185  CA-2024-141531 2024-12-29 2025-01-02  Standard Class
# 10187   10188  US-2024-126221 2024-12-30 2025-01-05  Standard Class
#
#       Customer ID   Customer Name      Segment Country/Region          City  \
# ...

# %%
data.set_index("Order Date")
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2021-01-03       1  US-2021-103800 2021-01-07  Standard Class    DP-13000
# 2021-01-04       2  US-2021-112326 2021-01-08  Standard Class    PO-19195
# 2021-01-04       3  US-2021-112326 2021-01-08  Standard Class    PO-19195
# 2021-01-04       4  US-2021-112326 2021-01-08  Standard Class    PO-19195
# 2021-01-05       5  US-2021-141817 2021-01-12  Standard Class    MB-18085
# ...            ...             ...        ...             ...         ...
# 2024-12-30   10190  US-2024-143259 2025-01-03  Standard Class    PO-18865
# 2024-12-30   10191  US-2024-115427 2025-01-03  Standard Class    EB-13975
# 2024-12-30   10192  US-2024-156720 2025-01-03  Standard Class    JM-15580
# 2024-12-30   10193  US-2024-143259 2025-01-03  Standard Class    PO-18865
# 2024-12-30   10194  CA-2024-143500 2025-01-03  Standard Class    HO-15230
#
# ...

# %%
import pandas as pd
data=pd.read_excel("/content/missing data 1.xlsx")
data
# Out:
#         Date  Temperature  Humidity
# 0 2025-11-01           29        60
# 1 2025-11-03           30        58
# 2 2025-11-04           31        55
# 3 2025-11-06           28        65
# 4 2025-11-07           27        70

# %%
ind=pd.date_range('2025-11-01','2025-11-03')
index=pd.DatetimeIndex(ind)
data.reindex(index)
# Out:
#            Date  Temperature  Humidity
# 2025-11-01  NaT          NaN       NaN
# 2025-11-02  NaT          NaN       NaN
# 2025-11-03  NaT          NaN       NaN

# %%
new_df=data.fillna(0)
new_df
# Out:
#         Date  Temperature  Humidity
# 0 2025-11-01           29        60
# 1 2025-11-03           30        58
# 2 2025-11-04           31        55
# 3 2025-11-06           28        65
# 4 2025-11-07           27        70

# %% [markdown]
# # **fillna**

# %%
data=pd.read_excel("/content/fillna.xlsx")
data
# Out:
#         Date  Temperature  Humidity
# 0 2025-11-01         29.0      60.0
# 1 2025-11-02          NaN       NaN
# 2 2025-11-03         30.0      58.0
# 3 2025-11-04         31.0      55.0
# 4 2025-11-05          NaN       NaN
# 5 2025-11-06         28.0      65.0
# 6 2025-11-07         27.0      70.0

# %%
new_df=data.fillna(0)
new_df
# Out:
#         Date  Temperature  Humidity
# 0 2025-11-01         29.0      60.0
# 1 2025-11-02          0.0       0.0
# 2 2025-11-03         30.0      58.0
# 3 2025-11-04         31.0      55.0
# 4 2025-11-05          0.0       0.0
# 5 2025-11-06         28.0      65.0
# 6 2025-11-07         27.0      70.0

# %%
new_df=data.fillna({"Temperature":0})
new_df
# Out:
#         Date  Temperature  Humidity
# 0 2025-11-01         29.0      60.0
# 1 2025-11-02          0.0       NaN
# 2 2025-11-03         30.0      58.0
# 3 2025-11-04         31.0      55.0
# 4 2025-11-05          0.0       NaN
# 5 2025-11-06         28.0      65.0
# 6 2025-11-07         27.0      70.0

# %%
new_df=data.fillna({"Humidity":0})
new_df
# Out:
#         Date  Temperature  Humidity
# 0 2025-11-01         29.0      60.0
# 1 2025-11-02          NaN       0.0
# 2 2025-11-03         30.0      58.0
# 3 2025-11-04         31.0      55.0
# 4 2025-11-05          NaN       0.0
# 5 2025-11-06         28.0      65.0
# 6 2025-11-07         27.0      70.0

# %% [markdown]
# ### **fillna forward fill**

# %%
new_df=data.fillna(method='ffill')
new_df
# Out:
# /tmp/ipython-input-672065044.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df=data.fillna(method='ffill')
#         Date  Temperature  Humidity
# 0 2025-11-01         29.0      60.0
# 1 2025-11-02         29.0      60.0
# 2 2025-11-03         30.0      58.0
# 3 2025-11-04         31.0      55.0
# 4 2025-11-05         31.0      55.0
# 5 2025-11-06         28.0      65.0
# 6 2025-11-07         27.0      70.0

# %% [markdown]
# ### fillna backward fill

# %%
new_df=data.fillna(method='bfill')
new_df
# Out:
# /tmp/ipython-input-493313220.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df=data.fillna(method='bfill')
#         Date  Temperature  Humidity
# 0 2025-11-01         29.0      60.0
# 1 2025-11-02         30.0      58.0
# 2 2025-11-03         30.0      58.0
# 3 2025-11-04         31.0      55.0
# 4 2025-11-05         28.0      65.0
# 5 2025-11-06         28.0      65.0
# 6 2025-11-07         27.0      70.0

# %%
new_df=data.fillna(method='ffill',limit=1)
new_df
# Out:
# /tmp/ipython-input-4188246909.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df=data.fillna(method='ffill',limit=1)
#         Date  Temperature  Humidity
# 0 2025-11-01         29.0      60.0
# 1 2025-11-02         29.0      60.0
# 2 2025-11-03         30.0      58.0
# 3 2025-11-04         31.0      55.0
# 4 2025-11-05         31.0      55.0
# 5 2025-11-06         28.0      65.0
# 6 2025-11-07         27.0      70.0

# %%
new_df=data.interpolate()
new_df
# Out:
#         Date  Temperature  Humidity
# 0 2025-11-01         29.0      60.0
# 1 2025-11-02         29.5      59.0
# 2 2025-11-03         30.0      58.0
# 3 2025-11-04         31.0      55.0
# 4 2025-11-05         29.5      60.0
# 5 2025-11-06         28.0      65.0
# 6 2025-11-07         27.0      70.0

# %%
new_df=data.interpolate()
new_df
# Out:
#         Date  Temperature  Humidity
# 0 2025-11-01         29.0      60.0
# 1 2025-11-02         29.5      59.0
# 2 2025-11-03         30.0      58.0
# 3 2025-11-04         31.0      55.0
# 4 2025-11-05         29.5      60.0
# 5 2025-11-06         28.0      65.0
# 6 2025-11-07         27.0      70.0

# %%
data=pd.read_excel("/content/int.xlsx")
data
# Out:
#    Order_No  Sales
# 0         1  100.0
# 1         2    NaN
# 2         3  300.0
# 3         4    NaN
# 4         5  500.0

# %%
new_df=data.interpolate(method='linear')
new_df
# Out:
#    Order_No  Sales
# 0         1  100.0
# 1         2  200.0
# 2         3  300.0
# 3         4  400.0
# 4         5  500.0

# %% [markdown]
# # **dropna**

# %%
data=pd.read_excel("/content/int.xlsx")
data
# Out:
#    Order_No  Sales
# 0         1  100.0
# 1         2    NaN
# 2         3  300.0
# 3         4    NaN
# 4         5  500.0

# %%
new_df=data.dropna()
new_df
# Out:
#    Order_No  Sales
# 0         1  100.0
# 2         3  300.0
# 4         5  500.0

# %%
data=pd.read_excel("/content/int.xlsx")
data
# Out:
#    Order_No  Sales
# 0         1  100.0
# 1         2    NaN
# 2         3  300.0
# 3         4    NaN
# 4         5  500.0

# %%
new_df=data.dropna(how='all')
new_df
# Out:
#    Order_No  Sales
# 0         1  100.0
# 1         2    NaN
# 2         3  300.0
# 3         4    NaN
# 4         5  500.0

# %%
new_df=data.dropna(thresh=2)
new_df
# Out:
#    Order_No  Sales
# 0         1  100.0
# 2         3  300.0
# 4         5  500.0

# %%
data=pd.read_excel("/content/book2.xlsx")
data
# Out:
#    Order_No Product  Sales
# 0         1       A    100
# 1         2       B    200
# 2         3       C    300
# 3         2       B    200
# 4         1       A    100

# %% [markdown]
# # **duplicated**

# %%
print(data.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
print(data.duplicated().sum())
# Out:
# 2

# %% [markdown]
# # **replace**

# %%
data=pd.read_excel("/content/book2.xlsx")
data
# Out:
#    Order_No Product  Sales
# 0         1       A    100
# 1         2       B    200
# 2         3       C    300
# 3         2       B    200
# 4         1       A    100

# %%
data["Sales"].replace(100,np.nan)
# Out:
# 0      NaN
# 1    200.0
# 2    300.0
# 3    200.0
# 4      NaN
# Name: Sales, dtype: float64

# %%
import numpy as np
data.replace(100,np.nan)
# Out:
#    Order_No Product  Sales
# 0         1       A    NaN
# 1         2       B  200.0
# 2         3       C  300.0
# 3         2       B  200.0
# 4         1       A    NaN

# %%
data.replace([100,300],np.nan)
# Out:
#    Order_No Product  Sales
# 0         1       A    NaN
# 1         2       B  200.0
# 2         3       C    NaN
# 3         2       B  200.0
# 4         1       A    NaN

# %%
data["Product"].replace('A',np.nan)
# Out:
# 0    NaN
# 1      B
# 2      C
# 3      B
# 4    NaN
# Name: Product, dtype: object

# %%
import pandas as pd
data=pd.read_csv("/content/data.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2602438269.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("/content/data.csv")
#       3 data
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data.fillna(0,inplace=True)

# %%
data
# Out:
#   Name   Age Gender  Maths  Science  English
# 0    A  20.0      M     85       90       80
# 1    B  22.0      F     78       88       84
# 2    C  21.0      M     92       95       89
# 3    D  23.0      F     70       75       80
# 4    E   0.0      M     88       82       85

# %%
data['Age'].replace(0.0,"18+",inplace=True)
# Out:
# /tmp/ipython-input-1427134920.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].replace(0.0,"18+",inplace=True)

# %%
data
# Out:
#   Name   Age Gender  Maths  Science  English
# 0    A  20.0      M     85       90       80
# 1    B  22.0      F     78       88       84
# 2    C  21.0      M     92       95       89
# 3    D  23.0      F     70       75       80
# 4    E   18+      M     88       82       85

# %%
data['Age'].replace("18+",24,inplace=True)
# Out:
# /tmp/ipython-input-2703535892.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].replace("18+",24,inplace=True)
# /tmp/ipython-input-2703535892.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Age'].replace("18+",24,inplace=True)

# %%
data
# Out:
#   Name   Age Gender  Maths  Science  English
# 0    A  20.0      M     85       90       80
# 1    B  22.0      F     78       88       84
# 2    C  21.0      M     92       95       89
# 3    D  23.0      F     70       75       80
# 4    E  24.0      M     88       82       85

# %%
data['Age'].replace(24,data['Age'].median(),inplace=True)
data
# Out:
# /tmp/ipython-input-3217674775.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].replace(24,data['Age'].median(),inplace=True)
#   Name   Age Gender  Maths  Science  English
# 0    A  20.0      M     85       90       80
# 1    B  22.0      F     78       88       84
# 2    C  21.0      M     92       95       89
# 3    D  23.0      F     70       75       80
# 4    E  22.0      M     88       82       85

# %%
data['Age'].replace(22,data['Age'].mean(),inplace=True)
data
# Out:
# /tmp/ipython-input-2606089297.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].replace(22,data['Age'].mean(),inplace=True)
#   Name   Age Gender  Maths  Science  English
# 0    A  20.0      M     85       90       80
# 1    B  21.6      F     78       88       84
# 2    C  21.0      M     92       95       89
# 3    D  23.0      F     70       75       80
# 4    E  21.6      M     88       82       85

# %% [markdown]
# ## Group by

# %%
df=pd.read_excel("/content/city.xlsx")
df
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    rain
# 1  2017-01-02  new york           36          7   sunny
# 2  2017-01-03  new york           28         12    snow
# 3  2017-01-04  new york           33          7   sunny
# 4  2017-01-01    mumbai           90          5   sunny
# 5  2017-01-02    mumbai           85         12     fog
# 6  2017-01-03    mumbai           87         15     fog
# 7  2017-01-04    mumbai           92          5    rain
# 8  2017-01-01     paris           45         20   sunny
# 9  2017-01-02     paris           50         13  cloudy
# 10 2017-01-03     paris           54          8  cloudy
# 11 2017-01-04     paris           42         10  cloudy

# %%
df.groupby('city')

# %%
df.groupby('city')["windspeed"].sum()
# Out:
# city
# mumbai      37
# new york    32
# paris       51
# Name: windspeed, dtype: int64

# %%
df.groupby('city')['temperature'].sum()
# Out:
# city
# mumbai      354
# new york    129
# paris       191
# Name: temperature, dtype: int64

# %%
grp_result=df.groupby("city")

# %%
grp_result.get_group('mumbai')
# Out:
#          day    city  temperature  windspeed  event
# 4 2017-01-01  mumbai           90          5  sunny
# 5 2017-01-02  mumbai           85         12    fog
# 6 2017-01-03  mumbai           87         15    fog
# 7 2017-01-04  mumbai           92          5   rain

# %%
for city,city_df in grp_result:
  print(city)
  print(city_df)
# Out:
# mumbai
#          day    city  temperature  windspeed  event
# 4 2017-01-01  mumbai           90          5  sunny
# 5 2017-01-02  mumbai           85         12    fog
# 6 2017-01-03  mumbai           87         15    fog
# 7 2017-01-04  mumbai           92          5   rain
# new york
#          day      city  temperature  windspeed  event
# 0 2017-01-01  new york           32          6   rain
# 1 2017-01-02  new york           36          7  sunny
# 2 2017-01-03  new york           28         12   snow
# 3 2017-01-04  new york           33          7  sunny
# paris
#           day   city  temperature  windspeed   event
# 8  2017-01-01  paris           45         20   sunny
# 9  2017-01-02  paris           50         13  cloudy
# 10 2017-01-03  paris           54          8  cloudy
# 11 2017-01-04  paris           42         10  cloudy

# %%
grp_result.max()
# Out:
#                 day  temperature  windspeed  event
# city
# mumbai   2017-01-04           92         15  sunny
# new york 2017-01-04           36         12  sunny
# paris    2017-01-04           54         20  sunny

# %%
grp_result.min()
# Out:
#                 day  temperature  windspeed   event
# city
# mumbai   2017-01-01           85          5     fog
# new york 2017-01-01           28          6    rain
# paris    2017-01-01           42          8  cloudy

# %%
grp_result["temperature"].mean()
# Out:
# city
# mumbai      88.50
# new york    32.25
# paris       47.75
# Name: temperature, dtype: float64

# %%
grp_result.get_group('mumbai').max()
# Out:
# day            2017-01-04 00:00:00
# city                        mumbai
# temperature                     92
# windspeed                       15
# event                        sunny
# dtype: object

# %%
grp_result.get_group('new york').max()
# Out:
# day            2017-01-04 00:00:00
# city                      new york
# temperature                     36
# windspeed                       12
# event                        sunny
# dtype: object

# %%
grp_result.get_group('new york').min()
# Out:
# day            2017-01-01 00:00:00
# city                      new york
# temperature                     28
# windspeed                        6
# event                         rain
# dtype: object

# %%
grp=df.groupby(['city','event'])
grp

# %%
grp.get_group(('new york','sunny'))
# Out:
#          day      city  temperature  windspeed  event
# 1 2017-01-02  new york           36          7  sunny
# 3 2017-01-04  new york           33          7  sunny

# %%
for city,city_df in grp:
  print(city)
  print('city_df')
# Out:
# ('mumbai', 'fog')
# city_df
# ('mumbai', 'rain')
# city_df
# ('mumbai', 'sunny')
# city_df
# ('new york', 'rain')
# city_df
# ('new york', 'snow')
# city_df
# ('new york', 'sunny')
# city_df
# ('paris', 'cloudy')
# city_df
# ('paris', 'sunny')
# city_df

# %% [markdown]
# ## CONCAT

# %%
tcs={'id':[101,102,103,104],
     'name':["mithun","dipin","jose","rahul"],
     'age':[25,26,27,28]}

wipro={'id':[101,102,103,104],
       'name':["dev","sreenath","sreerag","shafeel"],
       'age':[24,24,27,26]}

tcs_emp=pd.DataFrame(tcs)
wipro_emp=pd.DataFrame(wipro)
pd.concat([tcs_emp,wipro_emp])
# Out:
#     id      name  age
# 0  101    mithun   25
# 1  102     dipin   26
# 2  103      jose   27
# 3  104     rahul   28
# 0  101       dev   24
# 1  102  sreenath   24
# 2  103   sreerag   27
# 3  104   shafeel   26

# %%
pd.concat([tcs_emp,wipro_emp],ignore_index=True)
# Out:
#     id      name  age
# 0  101    mithun   25
# 1  102     dipin   26
# 2  103      jose   27
# 3  104     rahul   28
# 4  101       dev   24
# 5  102  sreenath   24
# 6  103   sreerag   27
# 7  104   shafeel   26

# %%
data=pd.concat([tcs_emp,wipro_emp],keys=['TCS','WIPRO'])
data
# Out:
#           id      name  age
# TCS   0  101    mithun   25
#       1  102     dipin   26
#       2  103      jose   27
#       3  104     rahul   28
# WIPRO 0  101       dev   24
#       1  102  sreenath   24
#       2  103   sreerag   27
#       3  104   shafeel   26

# %%
data=pd.concat([tcs_emp,wipro_emp],axis=1)
data
# Out:
#     id    name  age   id      name  age
# 0  101  mithun   25  101       dev   24
# 1  102   dipin   26  102  sreenath   24
# 2  103    jose   27  103   sreerag   27
# 3  104   rahul   28  104   shafeel   26

# %%
salary=pd.Series([65000,75000,15000,25000],name='salary')
pd.concat([tcs_emp,salary],axis=1)
# Out:
#     id    name  age  salary
# 0  101  mithun   25   65000
# 1  102   dipin   26   75000
# 2  103    jose   27   15000
# 3  104   rahul   28   25000

# %%
salary=pd.Series([75000,45000,15000,35000],name='salary')
pd.concat([wipro_emp,salary],axis=1)
# Out:
#     id      name  age  salary
# 0  101       dev   24   75000
# 1  102  sreenath   24   45000
# 2  103   sreerag   27   15000
# 3  104   shafeel   26   35000

# %% [markdown]
# # MERGE

# %%
tcs={'id':[101,102,103,104],
     'name':["mithun","dipin","jose","rahul"],
     'age':[25,26,27,28]}
wipro={'id':[101,102,103,104],
       'name':["dev","sreenath","sreerag","shafeel"],
       'salary':['25000','34000','37000','20000']}
tcs_emp=pd.DataFrame(tcs)
wipro_emp=pd.DataFrame(wipro)
pd.merge(tcs_emp,wipro_emp,on='id')
pd.merge(tcs_emp,wipro_emp,on='id',suffixes=['left','right'])
# Out:
#     id nameleft  age nameright salary
# 0  101   mithun   25       dev  25000
# 1  102    dipin   26  sreenath  34000
# 2  103     jose   27   sreerag  37000
# 3  104    rahul   28   shafeel  20000

# %%
pd.merge(tcs_emp,wipro_emp,on='id',how='outer')
# Out:
#     id  name_x  age    name_y salary
# 0  101  mithun   25       dev  25000
# 1  102   dipin   26  sreenath  34000
# 2  103    jose   27   sreerag  37000
# 3  104   rahul   28   shafeel  20000

# %%
pd.merge(tcs_emp,wipro_emp,on='id',how='outer',indicator=True)
# Out:
#     id  name_x  age    name_y salary _merge
# 0  101  mithun   25       dev  25000   both
# 1  102   dipin   26  sreenath  34000   both
# 2  103    jose   27   sreerag  37000   both
# 3  104   rahul   28   shafeel  20000   both

# %%
pd.merge(tcs_emp,wipro_emp,on='id',how='left')
# Out:
#     id  name_x  age    name_y salary
# 0  101  mithun   25       dev  25000
# 1  102   dipin   26  sreenath  34000
# 2  103    jose   27   sreerag  37000
# 3  104   rahul   28   shafeel  20000

# %%
pd.merge(tcs_emp,wipro_emp,on='id',how='right')
# Out:
#     id  name_x  age    name_y salary
# 0  101  mithun   25       dev  25000
# 1  102   dipin   26  sreenath  34000
# 2  103    jose   27   sreerag  37000
# 3  104   rahul   28   shafeel  20000

# %% [markdown]
# # Pivot

# %%
data=pd.read_excel("/content/city.xlsx")
data
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    rain
# 1  2017-01-02  new york           36          7   sunny
# 2  2017-01-03  new york           28         12    snow
# 3  2017-01-04  new york           33          7   sunny
# 4  2017-01-01    mumbai           90          5   sunny
# 5  2017-01-02    mumbai           85         12     fog
# 6  2017-01-03    mumbai           87         15     fog
# 7  2017-01-04    mumbai           92          5    rain
# 8  2017-01-01     paris           45         20   sunny
# 9  2017-01-02     paris           50         13  cloudy
# 10 2017-01-03     paris           54          8  cloudy
# 11 2017-01-04     paris           42         10  cloudy

# %%
data.pivot(index='day',columns='city')
# Out:
#            temperature                windspeed                 event  \
# city            mumbai new york paris    mumbai new york paris mumbai
# day
# 2017-01-01          90       32    45         5        6    20  sunny
# 2017-01-02          85       36    50        12        7    13    fog
# 2017-01-03          87       28    54        15       12     8    fog
# 2017-01-04          92       33    42         5        7    10   rain
#
#
# city       new york   paris
# day
# 2017-01-01     rain   sunny
# 2017-01-02    sunny  cloudy
# 2017-01-03     snow  cloudy
# 2017-01-04    sunny  cloudy

# %%
data.pivot(index='day',columns='city',values='temperature')
# Out:
# city        mumbai  new york  paris
# day
# 2017-01-01      90        32     45
# 2017-01-02      85        36     50
# 2017-01-03      87        28     54
# 2017-01-04      92        33     42

# %%
data=pd.read_excel("/content/city.xlsx")
data
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    rain
# 1  2017-01-02  new york           36          7   sunny
# 2  2017-01-03  new york           28         12    snow
# 3  2017-01-04  new york           33          7   sunny
# 4  2017-01-01    mumbai           90          5   sunny
# 5  2017-01-02    mumbai           85         12     fog
# 6  2017-01-03    mumbai           87         15     fog
# 7  2017-01-04    mumbai           92          5    rain
# 8  2017-01-01     paris           45         20   sunny
# 9  2017-01-02     paris           50         13  cloudy
# 10 2017-01-03     paris           54          8  cloudy
# 11 2017-01-04     paris           42         10  cloudy

# %%
data.pivot_table(index='city',columns='day',values='windspeed')
# Out:
# day       2017-01-01  2017-01-02  2017-01-03  2017-01-04
# city
# mumbai           5.0        12.0        15.0         5.0
# new york         6.0         7.0        12.0         7.0
# paris           20.0        13.0         8.0        10.0

# %%
data.pivot_table(index='city',columns='day',aggfunc='sum')
# Out:
#               event                                  temperature             \
# day      2017-01-01 2017-01-02 2017-01-03 2017-01-04  2017-01-01 2017-01-02
# city
# mumbai        sunny        fog        fog       rain          90         85
# new york       rain      sunny       snow      sunny          32         36
# paris         sunny     cloudy     cloudy     cloudy          45         50
#
#                                 windspeed
# day      2017-01-03 2017-01-04 2017-01-01 2017-01-02 2017-01-03 2017-01-04
# city
# mumbai           87         92          5         12         15          5
# new york         28         33          6          7         12          7
# paris            54         42         20         13          8         10

# %%
data.pivot_table(index='city',columns='day',aggfunc='sum',margins=True)
# Out:
#                        event                                          \
# day      2017-01-01 00:00:00 2017-01-02 00:00:00 2017-01-03 00:00:00
# city
# mumbai                 sunny                 fog                 fog
# new york                rain               sunny                snow
# paris                  sunny              cloudy              cloudy
# All           rainsunnysunny      sunnyfogcloudy       snowfogcloudy
#
#                               \
# day      2017-01-04 00:00:00
# city
# mumbai                  rain
# new york               sunny
# paris                 cloudy
# All          sunnyraincloudy
#
#                                                              \
# day                                                     All
# city
# mumbai                                      sunnyfogfograin
# new york                                 rainsunnysnowsunny
# paris                               sunnycloudycloudycloudy
# ...

# %%
data.pivot_table(index='city',columns='day',aggfunc='sum')
# Out:
#               event                                  temperature             \
# day      2017-01-01 2017-01-02 2017-01-03 2017-01-04  2017-01-01 2017-01-02
# city
# mumbai        sunny        fog        fog       rain          90         85
# new york       rain      sunny       snow      sunny          32         36
# paris         sunny     cloudy     cloudy     cloudy          45         50
#
#                                 windspeed
# day      2017-01-03 2017-01-04 2017-01-01 2017-01-02 2017-01-03 2017-01-04
# city
# mumbai           87         92          5         12         15          5
# new york         28         33          6          7         12          7
# paris            54         42         20         13          8         10

# %%
import pandas as pd
data=pd.read_excel("/content/city.xlsx")
data
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    rain
# 1  2017-01-02  new york           36          7   sunny
# 2  2017-01-03  new york           28         12    snow
# 3  2017-01-04  new york           33          7   sunny
# 4  2017-01-01    mumbai           90          5   sunny
# 5  2017-01-02    mumbai           85         12     fog
# 6  2017-01-03    mumbai           87         15     fog
# 7  2017-01-04    mumbai           92          5    rain
# 8  2017-01-01     paris           45         20   sunny
# 9  2017-01-02     paris           50         13  cloudy
# 10 2017-01-03     paris           54          8  cloudy
# 11 2017-01-04     paris           42         10  cloudy

# %%
data['day']=pd.to_datetime(data['day'])
data
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    rain
# 1  2017-01-02  new york           36          7   sunny
# 2  2017-01-03  new york           28         12    snow
# 3  2017-01-04  new york           33          7   sunny
# 4  2017-01-01    mumbai           90          5   sunny
# 5  2017-01-02    mumbai           85         12     fog
# 6  2017-01-03    mumbai           87         15     fog
# 7  2017-01-04    mumbai           92          5    rain
# 8  2017-01-01     paris           45         20   sunny
# 9  2017-01-02     paris           50         13  cloudy
# 10 2017-01-03     paris           54          8  cloudy
# 11 2017-01-04     paris           42         10  cloudy

# %%
data.set_index('day',inplace=True)
data
# Out:
#                 city  temperature  windspeed   event
# day
# 2017-01-01  new york           32          6    rain
# 2017-01-02  new york           36          7   sunny
# 2017-01-03  new york           28         12    snow
# 2017-01-04  new york           33          7   sunny
# 2017-01-01    mumbai           90          5   sunny
# 2017-01-02    mumbai           85         12     fog
# 2017-01-03    mumbai           87         15     fog
# 2017-01-04    mumbai           92          5    rain
# 2017-01-01     paris           45         20   sunny
# 2017-01-02     paris           50         13  cloudy
# 2017-01-03     paris           54          8  cloudy
# 2017-01-04     paris           42         10  cloudy

# %%
data.pivot_table(index=pd.Grouper(freq='M'),columns='city',aggfunc='count')
# Out:
# /tmp/ipython-input-2725734737.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data.pivot_table(index=pd.Grouper(freq='M'),columns='city',aggfunc='count')
#             event                temperature                windspeed  \
# city       mumbai new york paris      mumbai new york paris    mumbai
# day
# 2017-01-31      4        4     4           4        4     4         4
#
#
# city       new york paris
# day
# 2017-01-31        4     4

# %%
data.pivot_table(index=pd.Grouper(freq='M',key='day'),columns='city',aggfunc='sum')
# Out:
# /tmp/ipython-input-1499474636.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data.pivot_table(index=pd.Grouper(freq='M',key='day'),columns='city',aggfunc='sum')
#                       event                                               \
# city                 mumbai            new york                    paris
# day
# 2017-01-31  sunnyfogfograin  rainsunnysnowsunny  sunnycloudycloudycloudy
#
#            temperature                windspeed
# city            mumbai new york paris    mumbai new york paris
# day
# 2017-01-31         354      129   191        37       32    51

# %% [markdown]
# # MELT

# %% [markdown]
# **pandas.melt() is used to unpivot or reshape a DataFrame —
# it turns wide data (many columns) into long data (fewer columns)**

# %%
data=pd.read_excel("/content/dataframe.xlsx")
data
# Out:
#       city  2024_Jan  2024_Feb  2024_Mar
# 0    Delhi        25        27        30
# 1   Mumbai        30        32        33
# 2  Chennai        29        31        34

# %%
a=pd.melt(data,id_vars=["city"],value_vars=["2024_Jan","2024_Feb","2024_Mar"],var_name="month",value_name="temperature")
print(a)
# Out:
#       city     month  temperature
# 0    Delhi  2024_Jan           25
# 1   Mumbai  2024_Jan           30
# 2  Chennai  2024_Jan           29
# 3    Delhi  2024_Feb           27
# 4   Mumbai  2024_Feb           32
# 5  Chennai  2024_Feb           31
# 6    Delhi  2024_Mar           30
# 7   Mumbai  2024_Mar           33
# 8  Chennai  2024_Mar           34

# %% [markdown]
# # crosstab

# %%
data=pd.read_excel("/content/Book3.xlsx")
data
# Out:
#    Gender  Subject  Marks
# 0    Male    Maths     85
# 1  Female  Science     90
# 2  Female    Maths     78
# 3    Male  English     88
# 4    Male  Science     82
# 5  Female    Maths     91
# 6    Male  English     75
# 7  Female  Science     89

# %%
pd.crosstab(data.Gender,data.Subject)
# Out:
# Subject  English  Maths  Science
# Gender
# Female         0      2        2
# Male           2      1        1

# %%
pd.crosstab(data.Gender,data.Subject,margins=True)
# Out:
# Subject  English  Maths  Science  All
# Gender
# Female         0      2        2    4
# Male           2      1        1    4
# All            2      3        3    8

# %%
pd.crosstab(data.Gender,[data.Marks,data.Subject],margins=True)
# Out:
# Marks        75    78      82    85      88      89      90    91 All
# Subject English Maths Science Maths English Science Science Maths
# Gender
# Female        0     1       0     0       0       1       1     1   4
# Male          1     0       1     1       1       0       0     0   4
# All           1     1       1     1       1       1       1     1   8

# %%
import numpy as np

pd.crosstab(data.Gender,data.Subject,values=data.Marks,aggfunc=np.average)
# Out:
# Subject  English  Maths  Science
# Gender
# Female       NaN   84.5     89.5
# Male        81.5   85.0     82.0

# %% [markdown]
# # Datetime

# %%
import pandas as pd

data = pd.DataFrame({
    'date_str1': ['2024-01-15', '2024-02-20', 'invalid', '2024-04-10'],
    'date_str2': ['15/01/2024', '20/02/2024', '25/03/2024', '10/04/2024'],
    'timestamp_s': [1705296000, 1708387200, 1711324800, 1712707200]
})

data
# Out:
#     date_str1   date_str2  timestamp_s
# 0  2024-01-15  15/01/2024   1705296000
# 1  2024-02-20  20/02/2024   1708387200
# 2     invalid  25/03/2024   1711324800
# 3  2024-04-10  10/04/2024   1712707200

# %%
pd.to_datetime(data['date_str1'],errors='coerce')
# Out:
# 0   2024-01-15
# 1   2024-02-20
# 2          NaT
# 3   2024-04-10
# Name: date_str1, dtype: datetime64[ns]

# %%
pd.to_datetime(['10/23/2024'], dayfirst=True)
# Out:
# /tmp/ipython-input-83939145.py:1: UserWarning: Parsing dates in %m/%d/%Y format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   pd.to_datetime(['10/23/2024'], dayfirst=True)
# DatetimeIndex(['2024-10-23'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['10/04/2024'],format='%m/%d/%Y')
# Out:
# DatetimeIndex(['2024-10-04'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['06/25/2024'],dayfirst=True)
# Out:
# /tmp/ipython-input-2078070185.py:1: UserWarning: Parsing dates in %m/%d/%Y format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   pd.to_datetime(['06/25/2024'],dayfirst=True)
# DatetimeIndex(['2024-06-25'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['06/25/2024'],yearfirst=True)
# Out:
# DatetimeIndex(['2024-06-25'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['06/25/2024'],format='%m/%d/%Y')
# Out:
# DatetimeIndex(['2024-06-25'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(data['timestamp_s'],unit='s',origin='unix')
# Out:
# 0   2024-01-15 05:20:00
# 1   2024-02-20 00:00:00
# 2   2024-03-25 00:00:00
# 3   2024-04-10 00:00:00
# Name: timestamp_s, dtype: datetime64[ns]

# %%
pd.to_datetime(data['timestamp_s'],unit='s',utc=True)
# Out:
# 0   2024-01-15 05:20:00+00:00
# 1   2024-02-20 00:00:00+00:00
# 2   2024-03-25 00:00:00+00:00
# 3   2024-04-10 00:00:00+00:00
# Name: timestamp_s, dtype: datetime64[ns, UTC]

# %%
pd.to_datetime(data['date_str2'], cache=True)
# Out:
# /tmp/ipython-input-2975399766.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(data['date_str2'], cache=True)
# 0   2024-01-15
# 1   2024-02-20
# 2   2024-03-25
# 3   2024-04-10
# Name: date_str2, dtype: datetime64[ns]

# %%
p=pd.Period(2019)
p.start_time
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
p.end_time
# Out:
# Timestamp('2019-12-31 23:59:59.999999999')

# %%
p1=pd.Period('2017-01')

# %%
p1.start_time
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
p1.end_time
# Out:
# Timestamp('2017-01-31 23:59:59.999999999')

# %%
p.year
# Out:
# 2019

# %%
p1.year
# Out:
# 2017

# %%
p.asfreq('M',how='start')
# Out:
# Period('2019-01', 'M')

# %%
p1.asfreq('M',how='start')
# Out:
# Period('2017-01', 'M')

# %%
pd.period_range('2017','2019')
# Out:
# PeriodIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#              '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#              '2017-01-09', '2017-01-10',
#              ...
#              '2018-12-23', '2018-12-24', '2018-12-25', '2018-12-26',
#              '2018-12-27', '2018-12-28', '2018-12-29', '2018-12-30',
#              '2018-12-31', '2019-01-01'],
#             dtype='period[D]', length=731)

# %%
pd.period_range('2017','2019',freq='Y')
# Out:
# PeriodIndex(['2017', '2018', '2019'], dtype='period[Y-DEC]')

# %%
pd.period_range('2017-04','2017-07',freq='Q')
# Out:
# PeriodIndex(['2017Q2', '2017Q3'], dtype='period[Q-DEC]')

# %%
def square(x):
  return x*x
abc=[1,2,3,4,5]
out=list(map(square,abc))
out
# Out:
# [1, 4, 9, 16, 25]

# %%
data = {
    'day': ['2024-01-01','2024-01-02','2024-01-03','2024-01-04',
            '2024-01-01','2024-01-02','2024-01-03','2024-01-04',
            '2024-01-01','2024-01-02','2024-01-03','2024-01-04'],
    'city': ['Delhi','Delhi','Delhi','Delhi',
             'Mumbai','Mumbai','Mumbai','Mumbai',
             'Chennai','Chennai','Chennai','Chennai'],
    'temperature': [32,35,None,33,29,31,30,None,34,None,36,37],
    'humidity': [62,63,65,None,78,79,80,81,72,73,74,75],
    'windspeed': [12,14,13,11,7,8,None,9,10,11,12,None]
}
# Out:
# {'day': ['2024-01-01',
#   '2024-01-02',
#   '2024-01-03',
#   '2024-01-04',
#   '2024-01-01',
#   '2024-01-02',
#   '2024-01-03',
#   '2024-01-04',
#   '2024-01-01',
#   '2024-01-02',
#   '2024-01-03',
#   '2024-01-04'],
#  'city': ['Delhi',
#   'Delhi',
#   'Delhi',
#   'Delhi',
#   'Mumbai',
#   'Mumbai',
#   'Mumbai',
#   'Mumbai',
#   'Chennai',
#   'Chennai',
#   'Chennai',
#   'Chennai'],
#  'temperature': [32, 35, None, 33, 29, 31, 30, None, 34, None, 36, 37],
#  'humidity': [62, 63, 65, None, 78, 79, 80, 81, 72, 73, 74, 75],
#  'windspeed': [12, 14, 13, 11, 7, 8, None, 9, 10, 11, 12, None]}

# %%
data=pd.DataFrame(data)
def square(x):
  return x*x
dt=data[['temperature','humidity']].applymap(square)
dt
# Out:
# /tmp/ipython-input-3311127123.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   dt=data[['temperature','humidity']].applymap(square)
#     temperature  humidity
# 0        1024.0    3844.0
# 1        1225.0    3969.0
# 2           NaN    4225.0
# 3        1089.0       NaN
# 4         841.0    6084.0
# 5         961.0    6241.0
# 6         900.0    6400.0
# 7           NaN    6561.0
# 8        1156.0    5184.0
# 9           NaN    5329.0
# 10       1296.0    5476.0
# 11       1369.0    5625.0

# %%
data['temperature'].map(lambda x:x*x)
# Out:
# 0     1024.0
# 1     1225.0
# 2        NaN
# 3     1089.0
# 4      841.0
# 5      961.0
# 6      900.0
# 7        NaN
# 8     1156.0
# 9        NaN
# 10    1296.0
# 11    1369.0
# Name: temperature, dtype: float64
